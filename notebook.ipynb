# %% [markdown]
# # 1. Введение
#
# - В этом задании вам предстоит определить количество книг на фотографии.
#
#
# Я в интернете нашел несколько датасетов, связанные с книгами, чтобы обучить модель предсказывать. Возможно, из-за того, что я не очень внимательно смотрел на датасеты, то будет дисбаланс.
# Сами датасеты:
# - https://universe.roboflow.com/valuable-object-detection/book-tjl7z
# - https://universe.roboflow.com/books-mnb9z/books-7vad0
# - https://universe.roboflow.com/book-mxasl/book-cduc4
# - https://universe.roboflow.com/books-3jjp1/book-detection-aafpi

# %% [markdown]
# # 2. Установка зависимостей

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.3 MB/s eta 0:00:00

# %% [markdown]
# Я выбрал YOLOv8s по нескольким причинам:
# - Простота и готовое решение — модель уже реализована и активно поддерживается, поэтому нет смысла изобретать велосипед и писать собственную архитектуру с нуля.
# - Скорость работы — YOLOv8s достаточно лёгкая, хорошо подходит для обучения и инференса даже в Colab без серьёзных требований к железу.
# - Поддержка датасетов — многие открытые датасеты для задач детекции книг уже размечены под формат YOLOv8, что сильно ускоряет подготовку данных и запуск обучения.

# %% [markdown]
# # 3. Обработка датасетов

# %%
import os, zipfile, random, shutil, glob

# Пути к архивам
zips = [
    "/content/Book Detection.v1i.yolov8.zip",
    "/content/Book.v1i.yolov8.zip",
    "/content/books.v1-roboflow-instant-1--eval-.yolov8.zip",
    "/content/book.v1i.yolov8 (1).zip"
]

datasets_dir = "/content/datasets"
os.makedirs(datasets_dir, exist_ok=True)

# Разархивируем каждый датасет
extracted_dirs = []
for zip_path in zips:
    folder_name = os.path.splitext(os.path.basename(zip_path))[0]
    extract_path = os.path.join(datasets_dir, folder_name)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    extracted_dirs.append(extract_path)

# Начинаем собирать датасеты в одно место
combined_dir = os.path.join(datasets_dir, "books_combined_all")
for split in ["train", "valid", "test"]:
    for sub in ["images", "labels"]:
        os.makedirs(os.path.join(combined_dir, split, sub), exist_ok=True)

# Функция для копирования всех картинок и аннотаций
def copy_all_data(src_dir, split):
    src_img_dir = os.path.join(src_dir, split, "images")
    src_lbl_dir = os.path.join(src_dir, split, "labels")
    dst_img_dir = os.path.join(combined_dir, split, "images")
    dst_lbl_dir = os.path.join(combined_dir, split, "labels")
    for img_path in glob.glob(os.path.join(src_img_dir, "*.*")):
        filename = os.path.basename(img_path)
        stem, _ = os.path.splitext(filename)
        label_path = os.path.join(src_lbl_dir, stem + ".txt")
        shutil.copy(img_path, os.path.join(dst_img_dir, filename))
        if os.path.exists(label_path):
            shutil.copy(label_path, os.path.join(dst_lbl_dir, stem + ".txt"))

# Копируем данные из всех датасетов
for d in extracted_dirs:
    for split in ["train", "valid", "test"]:
        copy_all_data(d, split)

print("Все изображения и разметка объединены")
# Out:
# Все изображения и разметка объединены

# %% [markdown]
# Здесь я загрузил датасеты вручную в соотвествующую директорию. Далее объединил эти датасеты, чтобы обучить модель.

# %%
yaml_path = os.path.join(combined_dir, "data.yaml")

yaml_content = f"""
train: {combined_dir}/train/images
val: {combined_dir}/valid/images
test: {combined_dir}/test/images

nc: 1
names: ["book"]
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("data.yaml создан:", yaml_path)
# Out:
# data.yaml создан: /content/datasets/books_combined_all/data.yaml

# %% [markdown]
# Создал data.yml для модели, чтобы она могла обучаться

# %% [markdown]
# # 4. Обучение модели

# %%
# !yolo task=detect mode=train \
    model=yolov8s.pt \
    data=/content/datasets/books_combined_all/data.yaml \
    epochs=20 \
    imgsz=1020  \
    batch=16 \
    device=0 \
    workers=8 \
    augment=True \
    cache=True
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/books_combined_all/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1020, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[1020] must be multiple of max stride 32, updating to [1024]
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1502.4±552.2 MB/s, size: 41.4 KB)
# train: Scanning /content/datasets/books_combined_all/train/labels.cache... 3027 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3027/3027 40.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 20354, len(boxes) = 22685. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# WARNING ⚠️ train: 13.3GB RAM required to cache images with 50% safety margin but only 9.2/12.7GB available, not caching images
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1096.8±500.9 MB/s, size: 43.1 KB)
# val: Scanning /content/datasets/books_combined_all/valid/labels.cache... 644 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 644/644 4.6Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4622, len(boxes) = 5096. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (1.9GB RAM): 100% ━━━━━━━━━━━━ 644/644 80.3it/s 8.0s
# Plotting labels to /content/runs/detect/train6/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train6
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      9.15G      1.633      1.549      1.602         45       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.4s
#                    all        644       5096      0.574      0.538      0.528      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      9.29G      1.535      1.302      1.539         41       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.8it/s 11.9s
#                    all        644       5096      0.748      0.576      0.673      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      9.36G      1.464      1.219        1.5         44       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.6s
#                    all        644       5096      0.725      0.559      0.666      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      9.03G      1.393      1.162      1.444        101       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.5s
#                    all        644       5096      0.759      0.634      0.745      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20       9.3G      1.304      1.062      1.377         30       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.8it/s 11.9s
#                    all        644       5096      0.742      0.721      0.788      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      9.11G      1.239     0.9896      1.335         12       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.0s
#                    all        644       5096      0.803      0.777      0.834      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      8.91G      1.193     0.9377      1.299         47       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.8it/s 11.8s
#                    all        644       5096      0.781      0.746      0.825      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      8.91G      1.133     0.8783      1.267         91       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.3s
#                    all        644       5096      0.829      0.805      0.868      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      9.05G      1.096     0.8346       1.25         20       1024: 100% ━━━━━━━━━━━━ 190/190 1.4it/s 2:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.8it/s 11.5s
#                    all        644       5096      0.796      0.788      0.859      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20       9.4G      1.082     0.8133      1.234         36       1024: 100% ━━━━━━━━━━━━ 190/190 1.5it/s 2:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.3s
#                    all        644       5096      0.855      0.819      0.888      0.592
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      8.58G      1.154     0.8395      1.255         93       1024: 50% ━━━━━━────── 95/190 1.5it/s 1:07<1:05

# %% [markdown]
# Здесь происходит обучение модели.

# %% [markdown]
# # 4. Формирование ответов

# %%
import pandas as pd
from ultralytics import YOLO

# Разархивируем тестовые изображения
zip_path = "/content/task_images.zip"
extract_dir = "/content/task_images"
os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Картинки лежат внутри task_images/task_images/
src_dir = os.path.join(extract_dir, "task_images")
test_dir = "/content/test_images"
os.makedirs(test_dir, exist_ok=True)

import shutil
for img_path in glob.glob(os.path.join(src_dir, "*.*")):
    shutil.copy(img_path, test_dir)

print(f"Все {len(os.listdir(test_dir))} изображений готовы для инференса")

# Загружаем обученную модель
model = YOLO("/content/runs/detect/train3/weights/best.pt") # Здесь надо указать путь на последнюю обученную модель

# Подсчёт книг на всех изображениях
image_paths = glob.glob(os.path.join(test_dir, "*.*"))
results_list = []

for img_path in image_paths:
    result = model.predict(img_path, imgsz=1020, conf=0.3) # потому что картинки больше, чем в обучающей выборке
    n_books = len(result[0].boxes)  # количество боксов
    image_id = os.path.basename(img_path)
    results_list.append([image_id, n_books])

# Сохраняем в CSV
submission_df = pd.DataFrame(results_list, columns=['image_id', 'number_of_books'])
submission_df.to_csv('solution.csv', index=False)

print("solution.csv создан")
# Out:
# Все 1148 изображений готовы для инференса
#
# image 1/1 /content/test_images/152.jpg: 960x736 2 books, 26.1ms
# Speed: 6.0ms preprocess, 26.1ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/38.jpg: 736x960 2 books, 26.2ms
# Speed: 6.8ms preprocess, 26.2ms inference, 6.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1078.jpg: 736x960 4 books, 25.0ms
# Speed: 9.4ms preprocess, 25.0ms inference, 4.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/0.jpg: 960x736 1 book, 26.3ms
# Speed: 4.3ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/782.jpg: 960x736 1 book, 24.8ms
# Speed: 3.6ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/939.jpg: 960x736 1 book, 24.8ms
# Speed: 3.6ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1054.jpg: 960x448 (no detections), 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 448)
#
# image 1/1 /content/test_images/183.jpg: 736x960 5 books, 19.4ms
# Speed: 6.8ms preprocess, 19.4ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/626.jpg: 736x960 (no detections), 18.5ms
# Speed: 6.7ms preprocess, 18.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1094.jpg: 672x960 3 books, 17.3ms
# Speed: 6.4ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 672, 960)
#
# image 1/1 /content/test_images/517.jpg: 960x736 (no detections), 19.4ms
# Speed: 3.2ms preprocess, 19.4ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1.jpg: 736x960 1 book, 19.4ms
# Speed: 6.4ms preprocess, 19.4ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/596.jpg: 960x736 1 book, 16.7ms
# Speed: 3.4ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/887.jpg: 960x736 1 book, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1132.jpg: 960x736 6 books, 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/623.jpg: 960x736 1 book, 15.7ms
# Speed: 3.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/22.jpg: 960x736 4 books, 15.6ms
# Speed: 2.9ms preprocess, 15.6ms inference, 4.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/651.jpg: 960x768 1 book, 16.8ms
# Speed: 3.3ms preprocess, 16.8ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/1146.jpg: 960x768 1 book, 14.2ms
# Speed: 8.0ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/1067.jpg: 736x960 7 books, 14.9ms
# Speed: 6.6ms preprocess, 14.9ms inference, 5.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1117.jpg: 960x736 (no detections), 15.1ms
# Speed: 4.6ms preprocess, 15.1ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1059.jpg: 960x736 1 book, 13.8ms
# Speed: 3.3ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/791.jpg: 736x960 14 books, 14.9ms
# Speed: 6.7ms preprocess, 14.9ms inference, 9.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/709.jpg: 960x736 (no detections), 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/118.jpg: 960x736 1 book, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/75.jpg: 960x736 1 book, 13.1ms
# Speed: 5.2ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1122.jpg: 960x736 1 book, 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 2.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/309.jpg: 736x960 1 book, 15.2ms
# Speed: 7.4ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/298.jpg: 960x448 1 book, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 448)
#
# image 1/1 /content/test_images/516.jpg: 960x736 (no detections), 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/750.jpg: 832x960 1 book, 15.1ms
# Speed: 7.2ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 832, 960)
#
# image 1/1 /content/test_images/454.jpg: 960x736 2 books, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/785.jpg: 960x736 1 book, 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/383.jpg: 960x736 1 book, 13.6ms
# Speed: 5.5ms preprocess, 13.6ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/235.jpg: 736x960 2 books, 17.4ms
# Speed: 7.1ms preprocess, 17.4ms inference, 2.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/663.jpg: 960x608 1 book, 15.4ms
# Speed: 4.1ms preprocess, 15.4ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 608)
#
# image 1/1 /content/test_images/914.jpg: 960x736 3 books, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 5.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/770.jpg: 960x736 1 book, 15.4ms
# Speed: 4.3ms preprocess, 15.4ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/411.jpg: 736x960 4 books, 14.0ms
# Speed: 8.3ms preprocess, 14.0ms inference, 4.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/737.jpg: 736x960 10 books, 12.7ms
# Speed: 9.8ms preprocess, 12.7ms inference, 6.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/584.jpg: 736x960 1 book, 12.8ms
# Speed: 4.2ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/206.jpg: 960x736 2 books, 13.6ms
# Speed: 3.7ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/10.jpg: 960x736 8 books, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/980.jpg: 960x736 4 books, 13.2ms
# Speed: 2.3ms preprocess, 13.2ms inference, 2.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/555.jpg: 640x960 5 books, 11.2ms
# Speed: 4.1ms preprocess, 11.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 960)
#
# image 1/1 /content/test_images/568.jpg: 736x960 (no detections), 13.7ms
# Speed: 4.1ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1100.jpg: 960x736 1 book, 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/12.jpg: 736x960 1 book, 13.6ms
# Speed: 4.2ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/931.jpg: 960x736 4 books, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/496.jpg: 960x736 2 books, 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/882.jpg: 960x736 1 book, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/571.jpg: 736x960 1 book, 14.2ms
# Speed: 4.2ms preprocess, 14.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/766.jpg: 960x736 1 book, 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/896.jpg: 704x960 6 books, 13.1ms
# Speed: 3.9ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 960)
#
# image 1/1 /content/test_images/275.jpg: 736x960 10 books, 13.3ms
# Speed: 4.3ms preprocess, 13.3ms inference, 4.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/73.jpg: 608x960 (no detections), 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 960)
#
# image 1/1 /content/test_images/288.jpg: 960x736 2 books, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/842.jpg: 960x736 (no detections), 12.8ms
# Speed: 2.6ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1127.jpg: 960x736 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/866.jpg: 960x736 (no detections), 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/780.jpg: 736x960 2 books, 14.2ms
# Speed: 4.1ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/446.jpg: 960x736 2 books, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/21.jpg: 960x736 3 books, 13.1ms
# Speed: 2.4ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/24.jpg: 736x960 1 book, 14.2ms
# Speed: 4.1ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/166.jpg: 960x736 1 book, 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1025.jpg: 544x960 3 books, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 960)
#
# image 1/1 /content/test_images/505.jpg: 960x864 (no detections), 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 864)
#
# image 1/1 /content/test_images/291.jpg: 960x736 1 book, 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1064.jpg: 736x960 1 book, 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/787.jpg: 960x736 (no detections), 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/257.jpg: 736x960 2 books, 14.3ms
# Speed: 4.0ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/382.jpg: 960x736 4 books, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/356.jpg: 960x960 3 books, 17.0ms
# Speed: 8.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/1093.jpg: 768x960 1 book, 13.9ms
# Speed: 4.4ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 960)
#
# image 1/1 /content/test_images/297.jpg: 736x960 (no detections), 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/822.jpg: 960x768 1 book, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/18.jpg: 960x736 7 books, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 3.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/280.jpg: 960x736 1 book, 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/229.jpg: 960x736 (no detections), 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/249.jpg: 960x800 1 book, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 800)
#
# image 1/1 /content/test_images/349.jpg: 960x736 1 book, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/119.jpg: 960x736 5 books, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 2.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1042.jpg: 960x736 1 book, 13.2ms
# Speed: 2.2ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/366.jpg: 960x544 1 book, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/1003.jpg: 960x736 3 books, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/936.jpg: 960x736 1 book, 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/664.jpg: 960x672 2 books, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 672)
#
# image 1/1 /content/test_images/969.jpg: 960x736 1 book, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/862.jpg: 736x960 3 books, 13.8ms
# Speed: 4.0ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1014.jpg: 960x928 1 book, 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 928)
#
# image 1/1 /content/test_images/943.jpg: 736x960 1 book, 15.0ms
# Speed: 3.6ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/396.jpg: 736x960 (no detections), 13.6ms
# Speed: 3.6ms preprocess, 13.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/14.jpg: 960x736 1 book, 13.7ms
# Speed: 3.8ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/798.jpg: 960x736 1 book, 13.9ms
# Speed: 2.3ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/86.jpg: 960x736 1 book, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/617.jpg: 960x832 1 book, 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 832)
#
# image 1/1 /content/test_images/334.jpg: 960x736 1 book, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1015.jpg: 960x736 1 book, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/715.jpg: 960x736 4 books, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 2.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/344.jpg: 736x960 5 books, 13.7ms
# Speed: 4.3ms preprocess, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/131.jpg: 960x736 3 books, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/542.jpg: 960x736 1 book, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/374.jpg: 960x736 (no detections), 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/296.jpg: 960x640 1 book, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 640)
#
# image 1/1 /content/test_images/548.jpg: 960x736 1 book, 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/502.jpg: 960x672 1 book, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 672)
#
# image 1/1 /content/test_images/457.jpg: 736x960 1 book, 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/683.jpg: 960x736 9 books, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 4.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/508.jpg: 960x832 5 books, 15.0ms
# Speed: 2.8ms preprocess, 15.0ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 832)
#
# image 1/1 /content/test_images/459.jpg: 832x960 (no detections), 15.4ms
# Speed: 4.6ms preprocess, 15.4ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 960)
#
# image 1/1 /content/test_images/62.jpg: 960x544 1 book, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/83.jpg: 960x736 1 book, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/734.jpg: 960x704 1 book, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 704)
#
# image 1/1 /content/test_images/3.jpg: 960x736 1 book, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/46.jpg: 960x768 1 book, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/424.jpg: 960x544 5 books, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/776.jpg: 960x864 2 books, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 864)
#
# image 1/1 /content/test_images/1049.jpg: 960x736 6 books, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 3.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/324.jpg: 960x736 4 books, 13.2ms
# Speed: 2.5ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/907.jpg: 736x960 (no detections), 13.7ms
# Speed: 4.2ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/267.jpg: 960x736 1 book, 13.2ms
# Speed: 2.2ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/409.jpg: 960x448 2 books, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 448)
#
# image 1/1 /content/test_images/531.jpg: 736x960 1 book, 13.6ms
# Speed: 4.2ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/441.jpg: 736x960 1 book, 12.7ms
# Speed: 4.2ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1077.jpg: 960x800 1 book, 14.5ms
# Speed: 2.7ms preprocess, 14.5ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 800)
#
# image 1/1 /content/test_images/395.jpg: 736x960 (no detections), 14.8ms
# Speed: 4.0ms preprocess, 14.8ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/397.jpg: 960x896 2 books, 15.7ms
# Speed: 2.7ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 896)
#
# image 1/1 /content/test_images/884.jpg: 960x736 3 books, 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/410.jpg: 736x960 1 book, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/43.jpg: 960x736 7 books, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 3.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/212.jpg: 960x736 2 books, 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/856.jpg: 960x736 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/644.jpg: 960x736 1 book, 12.7ms
# Speed: 2.9ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/998.jpg: 736x960 1 book, 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/177.jpg: 736x960 4 books, 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/225.jpg: 736x960 (no detections), 12.6ms
# Speed: 4.1ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1138.jpg: 736x960 1 book, 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/748.jpg: 960x736 1 book, 13.4ms
# Speed: 2.4ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/885.jpg: 736x960 1 book, 13.5ms
# Speed: 4.3ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/781.jpg: 960x864 1 book, 16.1ms
# Speed: 2.8ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 864)
#
# image 1/1 /content/test_images/1041.jpg: 960x960 2 books, 16.5ms
# Speed: 2.7ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/318.jpg: 960x736 1 book, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/550.jpg: 960x736 4 books, 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/54.jpg: 960x736 1 book, 13.3ms
# Speed: 3.1ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/774.jpg: 960x736 1 book, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/824.jpg: 960x736 3 books, 12.6ms
# Speed: 2.8ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/60.jpg: 736x960 4 books, 13.9ms
# Speed: 5.0ms preprocess, 13.9ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/910.jpg: 960x736 1 book, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/65.jpg: 960x736 1 book, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/666.jpg: 960x736 1 book, 13.0ms
# Speed: 4.7ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/949.jpg: 960x736 8 books, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 4.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1129.jpg: 544x960 1 book, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 960)
#
# image 1/1 /content/test_images/911.jpg: 960x736 (no detections), 13.4ms
# Speed: 2.8ms preprocess, 13.4ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/173.jpg: 960x736 1 book, 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1023.jpg: 960x960 (no detections), 17.3ms
# Speed: 3.1ms preprocess, 17.3ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/565.jpg: 960x736 4 books, 13.9ms
# Speed: 2.3ms preprocess, 13.9ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/201.jpg: 736x960 1 book, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/13.jpg: 960x736 4 books, 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/176.jpg: 960x736 2 books, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/847.jpg: 960x960 1 book, 17.0ms
# Speed: 3.1ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/933.jpg: 640x960 3 books, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 960)
#
# image 1/1 /content/test_images/103.jpg: 960x736 (no detections), 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/755.jpg: 960x960 2 books, 17.3ms
# Speed: 3.3ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/560.jpg: 960x800 1 book, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 800)
#
# image 1/1 /content/test_images/455.jpg: 960x544 1 book, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/244.jpg: 960x960 (no detections), 17.3ms
# Speed: 3.0ms preprocess, 17.3ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/226.jpg: 960x736 1 book, 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/544.jpg: 960x736 2 books, 13.0ms
# Speed: 2.5ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/284.jpg: 736x960 1 book, 13.9ms
# Speed: 4.4ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/199.jpg: 960x736 1 book, 13.6ms
# Speed: 3.4ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/968.jpg: 960x736 1 book, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/429.jpg: 960x736 2 books, 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1134.jpg: 960x736 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/208.jpg: 736x960 2 books, 13.7ms
# Speed: 4.5ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/277.jpg: 960x640 1 book, 11.6ms
# Speed: 4.1ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 640)
#
# image 1/1 /content/test_images/814.jpg: 960x736 6 books, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 3.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/359.jpg: 960x960 1 book, 16.4ms
# Speed: 3.1ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/1082.jpg: 512x960 5 books, 9.8ms
# Speed: 3.5ms preprocess, 9.8ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 960)
#
# image 1/1 /content/test_images/40.jpg: 960x736 1 book, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/773.jpg: 960x768 (no detections), 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/16.jpg: 736x960 2 books, 14.6ms
# Speed: 4.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/68.jpg: 960x736 1 book, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/935.jpg: 960x736 (no detections), 13.8ms
# Speed: 2.5ms preprocess, 13.8ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/930.jpg: 960x736 (no detections), 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/98.jpg: 960x480 (no detections), 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 480)
#
# image 1/1 /content/test_images/117.jpg: 960x960 (no detections), 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/215.jpg: 736x960 8 books, 14.9ms
# Speed: 6.8ms preprocess, 14.9ms inference, 7.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1052.jpg: 960x768 (no detections), 13.3ms
# Speed: 2.7ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/120.jpg: 736x960 2 books, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/361.jpg: 960x736 1 book, 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/955.jpg: 960x736 1 book, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/191.jpg: 544x960 2 books, 11.1ms
# Speed: 3.2ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 960)
#
# image 1/1 /content/test_images/612.jpg: 736x960 3 books, 13.5ms
# Speed: 4.3ms preprocess, 13.5ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/373.jpg: 960x736 1 book, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/264.jpg: 960x736 1 book, 13.0ms
# Speed: 2.4ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1125.jpg: 960x736 1 book, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/816.jpg: 960x736 3 books, 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/528.jpg: 960x736 1 book, 13.9ms
# Speed: 2.8ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1074.jpg: 960x544 8 books, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 4.1ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/1139.jpg: 960x928 1 book, 16.2ms
# Speed: 6.3ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 928)
#
# image 1/1 /content/test_images/209.jpg: 960x736 1 book, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/768.jpg: 960x736 (no detections), 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/222.jpg: 960x736 15 books, 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 7.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/167.jpg: 960x960 (no detections), 16.8ms
# Speed: 5.1ms preprocess, 16.8ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/812.jpg: 736x960 2 books, 14.5ms
# Speed: 4.2ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/341.jpg: 960x736 1 book, 13.7ms
# Speed: 3.1ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/480.jpg: 736x960 2 books, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/50.jpg: 960x736 1 book, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/574.jpg: 960x736 1 book, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/979.jpg: 960x736 1 book, 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1004.jpg: 736x960 3 books, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/601.jpg: 960x736 1 book, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/116.jpg: 736x960 2 books, 14.5ms
# Speed: 4.3ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/994.jpg: 960x736 1 book, 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/846.jpg: 736x960 3 books, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/67.jpg: 832x960 7 books, 14.5ms
# Speed: 4.4ms preprocess, 14.5ms inference, 3.6ms postprocess per image at shape (1, 3, 832, 960)
#
# image 1/1 /content/test_images/132.jpg: 736x960 (no detections), 14.2ms
# Speed: 4.2ms preprocess, 14.2ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/292.jpg: 960x736 1 book, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/376.jpg: 960x736 (no detections), 13.5ms
# Speed: 3.3ms preprocess, 13.5ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/5.jpg: 960x736 4 books, 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/794.jpg: 544x960 1 book, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 960)
#
# image 1/1 /content/test_images/76.jpg: 960x960 (no detections), 16.2ms
# Speed: 6.5ms preprocess, 16.2ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/185.jpg: 960x736 (no detections), 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/717.jpg: 960x736 1 book, 13.1ms
# Speed: 4.1ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/269.jpg: 736x960 5 books, 14.1ms
# Speed: 4.2ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/237.jpg: 960x736 1 book, 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/764.jpg: 960x736 1 book, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/304.jpg: 800x960 1 book, 15.1ms
# Speed: 4.8ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 960)
#
# image 1/1 /content/test_images/876.jpg: 960x736 1 book, 13.9ms
# Speed: 3.3ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/81.jpg: 960x736 5 books, 13.0ms
# Speed: 2.3ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/611.jpg: 960x768 1 book, 13.2ms
# Speed: 2.3ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/1128.jpg: 960x736 1 book, 14.0ms
# Speed: 3.5ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/287.jpg: 960x736 3 books, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/958.jpg: 768x960 1 book, 13.9ms
# Speed: 4.2ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 960)
#
# image 1/1 /content/test_images/523.jpg: 768x960 2 books, 13.8ms
# Speed: 4.4ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 960)
#
# image 1/1 /content/test_images/1096.jpg: 960x736 2 books, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/169.jpg: 960x736 3 books, 12.7ms
# Speed: 2.8ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1087.jpg: 736x960 4 books, 13.9ms
# Speed: 4.2ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/879.jpg: 960x736 1 book, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1107.jpg: 960x736 (no detections), 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/918.jpg: 960x736 (no detections), 13.9ms
# Speed: 2.7ms preprocess, 13.9ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/823.jpg: 736x960 1 book, 13.6ms
# Speed: 4.3ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/388.jpg: 736x960 1 book, 13.0ms
# Speed: 4.2ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1022.jpg: 960x960 1 book, 16.7ms
# Speed: 3.1ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/669.jpg: 960x736 (no detections), 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/915.jpg: 960x544 1 book, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/162.jpg: 736x960 (no detections), 13.3ms
# Speed: 4.5ms preprocess, 13.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/74.jpg: 960x736 6 books, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/462.jpg: 960x736 (no detections), 13.1ms
# Speed: 2.4ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/440.jpg: 960x736 1 book, 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/698.jpg: 736x960 1 book, 14.2ms
# Speed: 4.1ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/831.jpg: 960x736 1 book, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/461.jpg: 960x736 2 books, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/629.jpg: 960x800 1 book, 15.8ms
# Speed: 2.6ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 800)
#
# image 1/1 /content/test_images/105.jpg: 896x960 2 books, 15.5ms
# Speed: 5.2ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 960)
#
# image 1/1 /content/test_images/439.jpg: 960x736 1 book, 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/760.jpg: 960x640 1 book, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 640)
#
# image 1/1 /content/test_images/179.jpg: 960x736 1 book, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/978.jpg: 736x960 1 book, 14.2ms
# Speed: 4.2ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/624.jpg: 960x736 (no detections), 13.9ms
# Speed: 3.3ms preprocess, 13.9ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/499.jpg: 736x960 2 books, 13.6ms
# Speed: 5.9ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/656.jpg: 960x736 (no detections), 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/56.jpg: 960x736 2 books, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/327.jpg: 960x736 3 books, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/276.jpg: 736x960 1 book, 13.8ms
# Speed: 5.1ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1101.jpg: 960x960 5 books, 16.2ms
# Speed: 3.1ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/1044.jpg: 480x960 2 books, 10.1ms
# Speed: 3.9ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 960)
#
# image 1/1 /content/test_images/495.jpg: 736x960 1 book, 14.1ms
# Speed: 4.1ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/793.jpg: 800x960 (no detections), 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 960)
#
# image 1/1 /content/test_images/494.jpg: 736x960 4 books, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/379.jpg: 960x832 (no detections), 15.2ms
# Speed: 2.6ms preprocess, 15.2ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 832)
#
# image 1/1 /content/test_images/1115.jpg: 960x736 1 book, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/938.jpg: 736x960 4 books, 13.9ms
# Speed: 4.2ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/125.jpg: 960x736 1 book, 13.8ms
# Speed: 2.6ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/961.jpg: 768x960 4 books, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 2.8ms postprocess per image at shape (1, 3, 768, 960)
#
# image 1/1 /content/test_images/682.jpg: 960x736 1 book, 13.4ms
# Speed: 3.9ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/867.jpg: 960x960 (no detections), 16.6ms
# Speed: 3.1ms preprocess, 16.6ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/745.jpg: 928x960 2 books, 16.3ms
# Speed: 4.6ms preprocess, 16.3ms inference, 1.4ms postprocess per image at shape (1, 3, 928, 960)
#
# image 1/1 /content/test_images/678.jpg: 960x736 3 books, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/649.jpg: 736x960 (no detections), 13.8ms
# Speed: 4.2ms preprocess, 13.8ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/641.jpg: 960x736 (no detections), 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/308.jpg: 960x736 1 book, 13.3ms
# Speed: 2.4ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/665.jpg: 960x736 1 book, 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/863.jpg: 960x736 (no detections), 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/473.jpg: 960x736 1 book, 13.7ms
# Speed: 2.5ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1109.jpg: 544x960 3 books, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 960)
#
# image 1/1 /content/test_images/69.jpg: 736x960 (no detections), 13.3ms
# Speed: 4.3ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/434.jpg: 960x736 2 books, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/294.jpg: 768x960 1 book, 13.6ms
# Speed: 4.2ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 960)
#
# image 1/1 /content/test_images/679.jpg: 960x736 1 book, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/535.jpg: 960x736 1 book, 13.3ms
# Speed: 3.8ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/133.jpg: 960x736 1 book, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/398.jpg: 736x960 1 book, 14.1ms
# Speed: 6.4ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/360.jpg: 672x960 9 books, 11.8ms
# Speed: 4.2ms preprocess, 11.8ms inference, 5.0ms postprocess per image at shape (1, 3, 672, 960)
#
# ...
# Speed: 3.2ms preprocess, 13.4ms inference, 9.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/66.jpg: 736x960 (no detections), 13.8ms
# Speed: 6.7ms preprocess, 13.8ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/507.jpg: 960x736 1 book, 15.3ms
# Speed: 3.4ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/137.jpg: 960x736 1 book, 13.5ms
# Speed: 3.3ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1060.jpg: 960x960 4 books, 16.8ms
# Speed: 4.0ms preprocess, 16.8ms inference, 3.7ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/248.jpg: 448x960 4 books, 10.1ms
# Speed: 4.2ms preprocess, 10.1ms inference, 3.5ms postprocess per image at shape (1, 3, 448, 960)
#
# image 1/1 /content/test_images/877.jpg: 640x960 1 book, 11.4ms
# Speed: 5.8ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 960)
#
# image 1/1 /content/test_images/415.jpg: 960x736 1 book, 14.8ms
# Speed: 3.4ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1024.jpg: 960x736 (no detections), 13.1ms
# Speed: 3.3ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/145.jpg: 800x960 1 book, 14.7ms
# Speed: 6.2ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 960)
#
# image 1/1 /content/test_images/540.jpg: 960x736 (no detections), 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/873.jpg: 960x960 1 book, 17.0ms
# Speed: 4.4ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/135.jpg: 960x736 (no detections), 14.7ms
# Speed: 5.4ms preprocess, 14.7ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/625.jpg: 960x736 1 book, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/586.jpg: 960x736 1 book, 15.1ms
# Speed: 3.0ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/693.jpg: 736x960 18 books, 14.2ms
# Speed: 6.6ms preprocess, 14.2ms inference, 11.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1084.jpg: 960x736 1 book, 14.1ms
# Speed: 3.4ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/929.jpg: 736x960 1 book, 14.0ms
# Speed: 6.8ms preprocess, 14.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/855.jpg: 960x448 4 books, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 448)
#
# image 1/1 /content/test_images/646.jpg: 960x736 4 books, 14.1ms
# Speed: 3.3ms preprocess, 14.1ms inference, 4.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/974.jpg: 960x736 1 book, 13.2ms
# Speed: 3.7ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1046.jpg: 960x736 1 book, 14.7ms
# Speed: 5.6ms preprocess, 14.7ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/100.jpg: 960x768 (no detections), 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 768)
#
# image 1/1 /content/test_images/953.jpg: 960x736 1 book, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/340.jpg: 960x736 1 book, 13.2ms
# Speed: 5.2ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1040.jpg: 960x736 1 book, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 2.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/721.jpg: 960x736 1 book, 13.3ms
# Speed: 3.3ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/299.jpg: 960x736 1 book, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 4.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/687.jpg: 960x736 1 book, 18.2ms
# Speed: 5.0ms preprocess, 18.2ms inference, 3.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/984.jpg: 704x960 (no detections), 13.6ms
# Speed: 10.7ms preprocess, 13.6ms inference, 0.7ms postprocess per image at shape (1, 3, 704, 960)
#
# image 1/1 /content/test_images/310.jpg: 736x960 1 book, 16.8ms
# Speed: 8.6ms preprocess, 16.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/573.jpg: 960x640 2 books, 11.6ms
# Speed: 8.1ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 640)
#
# image 1/1 /content/test_images/285.jpg: 960x960 1 book, 16.5ms
# Speed: 4.6ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/1099.jpg: 960x736 3 books, 14.9ms
# Speed: 3.1ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/88.jpg: 960x544 1 book, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/759.jpg: 960x544 1 book, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/421.jpg: 960x736 7 books, 13.9ms
# Speed: 3.5ms preprocess, 13.9ms inference, 8.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/95.jpg: 960x736 7 books, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 6.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/742.jpg: 960x704 1 book, 15.4ms
# Speed: 3.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 704)
#
# image 1/1 /content/test_images/945.jpg: 736x960 (no detections), 13.8ms
# Speed: 6.6ms preprocess, 13.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1112.jpg: 960x960 (no detections), 17.1ms
# Speed: 4.3ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/904.jpg: 960x736 2 books, 15.3ms
# Speed: 4.5ms preprocess, 15.3ms inference, 3.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/940.jpg: 736x960 2 books, 13.9ms
# Speed: 8.3ms preprocess, 13.9ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/761.jpg: 960x544 1 book, 11.4ms
# Speed: 4.4ms preprocess, 11.4ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/1061.jpg: 960x544 1 book, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/889.jpg: 736x960 3 books, 14.6ms
# Speed: 8.8ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/210.jpg: 960x736 2 books, 14.0ms
# Speed: 5.2ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/1018.jpg: 960x736 1 book, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/894.jpg: 960x736 1 book, 13.3ms
# Speed: 5.2ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/189.jpg: 736x960 4 books, 14.1ms
# Speed: 6.8ms preprocess, 14.1ms inference, 5.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/70.jpg: 736x960 (no detections), 14.7ms
# Speed: 9.8ms preprocess, 14.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/326.jpg: 736x960 7 books, 14.5ms
# Speed: 9.5ms preprocess, 14.5ms inference, 7.3ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/36.jpg: 736x960 2 books, 13.1ms
# Speed: 9.9ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/605.jpg: 960x736 (no detections), 14.2ms
# Speed: 3.3ms preprocess, 14.2ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/403.jpg: 960x736 4 books, 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 4.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/919.jpg: 960x960 1 book, 17.4ms
# Speed: 4.5ms preprocess, 17.4ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/997.jpg: 640x960 (no detections), 14.1ms
# Speed: 6.6ms preprocess, 14.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 960)
#
# image 1/1 /content/test_images/796.jpg: 736x960 8 books, 15.3ms
# Speed: 10.0ms preprocess, 15.3ms inference, 9.4ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1106.jpg: 960x672 (no detections), 15.1ms
# Speed: 6.5ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 672)
#
# image 1/1 /content/test_images/967.jpg: 960x736 6 books, 14.1ms
# Speed: 4.3ms preprocess, 14.1ms inference, 6.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/482.jpg: 960x736 (no detections), 13.1ms
# Speed: 4.7ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/369.jpg: 736x960 1 book, 15.3ms
# Speed: 8.0ms preprocess, 15.3ms inference, 4.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/857.jpg: 960x544 2 books, 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 2.9ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/1031.jpg: 960x736 13 books, 15.8ms
# Speed: 3.6ms preprocess, 15.8ms inference, 18.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/89.jpg: 960x736 (no detections), 13.8ms
# Speed: 6.6ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/407.jpg: 960x736 2 books, 14.9ms
# Speed: 6.1ms preprocess, 14.9ms inference, 4.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/618.jpg: 736x960 (no detections), 14.4ms
# Speed: 6.6ms preprocess, 14.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1034.jpg: 960x736 1 book, 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/927.jpg: 960x736 1 book, 13.2ms
# Speed: 3.3ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/881.jpg: 736x960 1 book, 13.7ms
# Speed: 6.9ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/591.jpg: 960x736 1 book, 14.1ms
# Speed: 5.0ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/460.jpg: 960x736 1 book, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/32.jpg: 960x736 1 book, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/732.jpg: 960x736 22 books, 14.0ms
# Speed: 3.5ms preprocess, 14.0ms inference, 9.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/303.jpg: 960x736 1 book, 13.7ms
# Speed: 3.2ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/818.jpg: 960x736 17 books, 12.9ms
# Speed: 3.1ms preprocess, 12.9ms inference, 8.4ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/250.jpg: 960x736 (no detections), 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 0.7ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/336.jpg: 736x960 (no detections), 13.2ms
# Speed: 6.6ms preprocess, 13.2ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/1045.jpg: 960x736 1 book, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/381.jpg: 960x736 (no detections), 14.4ms
# Speed: 3.2ms preprocess, 14.4ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/522.jpg: 736x960 (no detections), 14.7ms
# Speed: 5.7ms preprocess, 14.7ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/4.jpg: 960x736 1 book, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/987.jpg: 736x960 1 book, 15.9ms
# Speed: 8.7ms preprocess, 15.9ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/140.jpg: 736x960 4 books, 12.9ms
# Speed: 7.0ms preprocess, 12.9ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/590.jpg: 960x736 2 books, 13.8ms
# Speed: 6.0ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/490.jpg: 736x960 2 books, 13.5ms
# Speed: 7.4ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/702.jpg: 960x736 1 book, 13.6ms
# Speed: 3.2ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/769.jpg: 960x736 1 book, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/954.jpg: 736x960 (no detections), 14.1ms
# Speed: 5.8ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/485.jpg: 960x928 6 books, 16.2ms
# Speed: 3.8ms preprocess, 16.2ms inference, 3.4ms postprocess per image at shape (1, 3, 960, 928)
#
# image 1/1 /content/test_images/996.jpg: 960x544 2 books, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 544)
#
# image 1/1 /content/test_images/807.jpg: 960x960 1 book, 16.6ms
# Speed: 4.2ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/488.jpg: 960x960 1 book, 16.4ms
# Speed: 7.2ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 960)
#
# image 1/1 /content/test_images/660.jpg: 960x736 2 books, 14.4ms
# Speed: 3.1ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/690.jpg: 736x960 2 books, 14.0ms
# Speed: 6.5ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/261.jpg: 736x960 1 book, 13.3ms
# Speed: 6.8ms preprocess, 13.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 960)
#
# image 1/1 /content/test_images/747.jpg: 960x736 2 books, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 736)
#
# image 1/1 /content/test_images/111.jpg: 736x960 2 books, 13.7ms
# Speed: 6.1ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
# solution.csv создан

# %% [markdown]
# Загрузил task_images.zip, также как и другие датасеты и предобработал пути. Подсчитал количества книг для каждого image_id. Сформировал solution.csv.

# %% [markdown]
# # Выводы
#
# Скорее всего низкая метрика связана с плохим сбором датасета, а также недостаточным хорошим обучением самой модели. Возможно, надо было показать моделе еще датасет с "некнигами", чтобы она могла более уверенно отличать их. Также, скорее всего, не хватило итераций для улучшения результата.
